# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import shap
import mlflow
import matplotlib.pyplot as plt

print("pandas   :", pd.__version__)
print("numpy    :", np.__version__)
print("xgboost  :", xgb.__version__)
print("shap     :", shap.__version__)
print("mlflow   :", mlflow.__version__)
print("")
print("Python 3.11 on Mac — fraud-env ready.")
# Out:
# pandas   : 2.3.3
# numpy    : 2.3.5
# xgboost  : 3.2.0
# shap     : 0.51.0
# mlflow   : 3.12.0
#
# Python 3.11 on Mac — fraud-env ready.
